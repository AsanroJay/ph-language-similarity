# %% [markdown]
# ## **Cleaning PALITO Dataset**

# %%
from pathlib import Path

print(Path.cwd())
# Out:
# c:\Source Code\AILRIC\ph-language-similarity\code

# %%
import re
regex = [
    r"([a-zA-Z]+:[A-Z][a-zA-Z]+)", #Remove title e.g Title: Acts
    r"([a-zA-Z]+\s+<.+>)", #Remove Acts <lbl>1</lbl>  
    r"(?<=\s{1})\d{1,3}(?=\s{1})", #Remove verse numbers within text
    r"/(?m)^\\?https?:\/\/.*$", #Remove links
]
